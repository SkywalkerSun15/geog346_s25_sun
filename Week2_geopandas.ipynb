# %% [markdown]
# # GeoPandas For Vector Data
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/giswqs/geog-510/blob/main/book/geospatial/geopandas.ipynb)
#
# ## Overview
#
# [GeoPandas](https://geopandas.org) is an open-source Python library that simplifies working with geospatial data by extending Pandas data structures. It seamlessly integrates geospatial operations with a pandas-like interface, allowing for the manipulation of geometric types such as points, lines, and polygons. GeoPandas combines the functionalities of Pandas and Shapely, enabling geospatial operations like spatial joins, buffering, intersections, and projections with ease.
#
# ## Learning Objectives
#
# By the end of this lecture, you should be able to:
#
# - Understand the basic data structures in GeoPandas: `GeoDataFrame` and `GeoSeries`.
# - Create `GeoDataFrames` from tabular data and geometric shapes.
# - Read and write geospatial data formats like Shapefile and GeoJSON.
# - Perform common geospatial operations such as measuring areas, distances, and spatial relationships.
# - Visualize geospatial data using Matplotlib and GeoPandas' built-in plotting functions.
# - Work with different Coordinate Reference Systems (CRS) and project geospatial data.
#
# ## Concepts
#
# The core data structures in GeoPandas are `GeoDataFrame` and `GeoSeries`. A `GeoDataFrame` extends the functionality of a Pandas DataFrame by adding a geometry column, allowing spatial data operations on geometric shapes. The `GeoSeries` handles geometric data (points, polygons, etc.).
#
# A `GeoDataFrame` can have multiple geometry columns, but only one is considered the active geometry at any time. All spatial operations are applied to this active geometry, accessible via the `.geometry` attribute.

# %% [markdown]
# ## Installing and Importing GeoPandas
#
# Before we begin, make sure you have geopandas installed. You can install it using:

# %%
# %pip install geopandas or type in mamba install -n geog346 -c conda-forge geopandas in your terminal

# %% [markdown]
# Once installed, import GeoPandas and other necessary libraries:

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## Creating GeoDataFrames
#
# A GeoDataFrame is a tabular data structure that contains a `geometry` column, which holds the geometric shapes. You can create a GeoDataFrame from a list of geometries or from a pandas DataFrame.

# %%
# Creating a GeoDataFrame from scratch
data = {
    "City": ["Tokyo", "New York", "London", "Paris"],
    "Latitude": [35.6895, 40.7128, 51.5074, 48.8566],
    "Longitude": [139.6917, -74.0060, -0.1278, 2.3522],
}

df = pd.DataFrame(data)
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))
gdf
# Out:
#        City  Latitude  Longitude                  geometry
# 0     Tokyo   35.6895   139.6917  POINT (139.6917 35.6895)
# 1  New York   40.7128   -74.0060   POINT (-74.006 40.7128)
# 2    London   51.5074    -0.1278   POINT (-0.1278 51.5074)
# 3     Paris   48.8566     2.3522    POINT (2.3522 48.8566)

# %% [markdown]
# ## Reading and Writing Geospatial Data
#
# GeoPandas allows reading and writing a variety of geospatial formats, such as Shapefiles, GeoJSON, and more. We'll use a GeoJSON dataset of New York City borough boundaries.
#
# ### Reading a GeoJSON File
#
# We'll load the New York boroughs dataset from a GeoJSON file hosted online.

# %% [markdown]
# This is first class of vector geopands operation

# %%
path = "https://github.com/opengeos/datasets/releases/download/vector/nybb.geojson"
gdf = gpd.read_file(path)
gdf.head()
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330470.010332  1.623820e+09
# 1         4         Queens  896344.047763  3.045213e+09
# 2         3       Brooklyn  741080.523166  1.937479e+09
# 3         1      Manhattan  359299.096471  6.364715e+08
# 4         2          Bronx  464392.991824  1.186925e+09
#
#                                             geometry
# 0  MULTIPOLYGON (((970217.022 145643.332, 970227....
# 1  MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 2  MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 3  MULTIPOLYGON (((981219.056 188655.316, 980940....
# 4  MULTIPOLYGON (((1012821.806 229228.265, 101278...

# %% [markdown]
# This `GeoDataFrame` contains several columns, including `BoroName`, which represents the names of the boroughs, and `geometry`, which stores the polygons for each borough.
#
# ### Writing to a GeoJSON File
#
# GeoPandas also supports saving geospatial data back to disk. For example, we can save the GeoDataFrame as a new GeoJSON file:

# %%
output_file = os.path.join("data", "nyc_boroughs.geojson")
gdf.to_file(output_file, driver="GeoJSON")
print(f"GeoDataFrame has been written to {output_file}")
# Out:
# GeoDataFrame has been written to data/nyc_boroughs.geojson

# %% [markdown]
# Similarly, you can write GeoDataFrames to other formats, such as Shapefiles, GeoPackage, and more.

# %%
output_file = os.path.join("data", "nyc_boroughs.shp")
gdf.to_file(output_file)
print(f"Shapefile has been written to {output_file}")
# Out:
# Shapefile has been written to data/nyc_boroughs.shp
# /Users/xiaozhongsun/miniconda3/envs/geog346/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1623819823.8099999 of field Shape_Area of feature 0 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/xiaozhongsun/miniconda3/envs/geog346/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 3045212795.1999998 of field Shape_Area of feature 1 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/xiaozhongsun/miniconda3/envs/geog346/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1937478507.6099999 of field Shape_Area of feature 2 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/xiaozhongsun/miniconda3/envs/geog346/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 636471539.77400005 of field Shape_Area of feature 3 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/xiaozhongsun/miniconda3/envs/geog346/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1186924686.49 of field Shape_Area of feature 4 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(

# %%
output_file = os.path.join("data", "nyc_boroughs.gpkg")
gdf.to_file(output_file, driver="GPKG")

# %% [markdown]
# ## Simple Accessors and Methods
#
# Now that we have the data, let's explore some simple GeoPandas methods to manipulate and analyze the geometric data.
#
# ### Measuring Area
#
# We can calculate the area of each borough. GeoPandas automatically calculates the area of each polygon:

# %%
# Set BoroName as the index for easier reference
gdf = gdf.set_index("BoroName")

# Calculate the area
gdf["area"] = gdf.area
gdf
# Out:
#                BoroCode     Shape_Leng    Shape_Area  \
# BoroName
# Staten Island         5  330470.010332  1.623820e+09
# Queens                4  896344.047763  3.045213e+09
# Brooklyn              3  741080.523166  1.937479e+09
# Manhattan             1  359299.096471  6.364715e+08
# Bronx                 2  464392.991824  1.186925e+09
#
#                                                         geometry          area
# BoroName
# Staten Island  MULTIPOLYGON (((970217.022 145643.332, 970227....  1.623822e+09
# Queens         MULTIPOLYGON (((1029606.077 156073.814, 102957...  3.045214e+09
# Brooklyn       MULTIPOLYGON (((1021176.479 151374.797, 102100...  1.937478e+09
# Manhattan      MULTIPOLYGON (((981219.056 188655.316, 980940....  6.364712e+08
# Bronx          MULTIPOLYGON (((1012821.806 229228.265, 101278...  1.186926e+09

# %% [markdown]
# ### Getting Polygon Boundaries and Centroids
#
# To get the boundary (lines) and centroid (center point) of each polygon:

# %%
# Get the boundary of each polygon
gdf["boundary"] = gdf.boundary

# Get the centroid of each polygon
gdf["centroid"] = gdf.centroid

gdf[["area", "boundary", "centroid"]]
# Out:
#                        area  \
# BoroName
# Staten Island  1.623822e+09
# Queens         3.045214e+09
# Brooklyn       1.937478e+09
# Manhattan      6.364712e+08
# Bronx          1.186926e+09
#
#                                                         boundary  \
# BoroName
# Staten Island  MULTILINESTRING ((970217.022 145643.332, 97022...
# Queens         MULTILINESTRING ((1029606.077 156073.814, 1029...
# Brooklyn       MULTILINESTRING ((1021176.479 151374.797, 1021...
# Manhattan      MULTILINESTRING ((981219.056 188655.316, 98094...
# Bronx          MULTILINESTRING ((1012821.806 229228.265, 1012...
#
#                                      centroid
# BoroName
# Staten Island    POINT (941639.45 150931.991)
# Queens         POINT (1034578.078 197116.604)
# Brooklyn        POINT (998769.115 174169.761)
# Manhattan       POINT (993336.965 222451.437)
# Bronx            POINT (1021174.79 249937.98)

# %% [markdown]
# ### Measuring Distance
#
# We can also measure the distance from each borough's centroid to a reference point, such as the centroid of Manhattan.

# %%
# Use Manhattan's centroid as the reference point
manhattan_centroid = gdf.loc["Manhattan", "centroid"]

# Calculate the distance from each centroid to Manhattan's centroid
gdf["distance_to_manhattan"] = gdf["centroid"].distance(manhattan_centroid)
gdf[["centroid", "distance_to_manhattan"]]
# Out:
#                                      centroid  distance_to_manhattan
# BoroName
# Staten Island    POINT (941639.45 150931.991)           88247.742789
# Queens         POINT (1034578.078 197116.604)           48401.272479
# Brooklyn        POINT (998769.115 174169.761)           48586.299386
# Manhattan       POINT (993336.965 222451.437)               0.000000
# Bronx            POINT (1021174.79 249937.98)           39121.024479

# %% [markdown]
# ### Calculating Mean Distance
#
# We can calculate the mean distance between the borough centroids and Manhattan:

# %%
mean_distance = gdf["distance_to_manhattan"].mean()
print(f"Mean distance to Manhattan: {mean_distance} units")
# Out:
# Mean distance to Manhattan: 44871.26782659276 units

# %% [markdown]
# ## Plotting Geospatial Data
#
# GeoPandas integrates with Matplotlib for easy plotting of geospatial data. Let's create some maps to visualize the data.
#
# ### Plotting the Area of Each Borough
#
# We can color the boroughs based on their area and display a legend:

# %%
gdf.plot("area", legend=True, figsize=(10, 6))
plt.title("NYC Boroughs by Area")
plt.show()

# %% [markdown]
# ### Plotting Centroids and Boundaries
#
# We can also plot the centroids and boundaries:

# %%
# Plot the boundaries and centroids
ax = gdf["geometry"].plot(figsize=(10, 6), edgecolor="black")
gdf["centroid"].plot(ax=ax, color="red", markersize=50)
plt.title("NYC Borough Boundaries and Centroids")
plt.show()

# %% [markdown]
# You can also explore your data interactively using `GeoDataFrame.explore()`, which behaves in the same way `plot()` does but returns an interactive map instead.

# %%
gdf.explore("area", legend=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_203f6baa6cbabf25b54a943e81210d89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_203f6baa6cbabf25b54a943e81210d89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_203f6baa6cbabf25b54a943e81210d89 = L.map(
#                 &quot;map_203f6baa6cbabf25b54a943e81210d89&quot;,
#                 {
#                     center: [40.705823757883195, -73.97780068328092],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_203f6baa6cbabf25b54a943e81210d89);
#
#
#
#
#
#             var tile_layer_2c4b062c11b9753e97958e52627a2615 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2c4b062c11b9753e97958e52627a2615.addTo(map_203f6baa6cbabf25b54a943e81210d89);
#
#
#             map_203f6baa6cbabf25b54a943e81210d89.fitBounds(
#                 [[40.49611512042366, -74.25559212524018], [40.91553239534272, -73.70000924132164]],
#                 {}
#             );
#
#
#         function geo_json_f4f432e340e6337c45e24db4bcfd3a9c_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#297a8e&quot;, &quot;fillColor&quot;: &quot;#297a8e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#1f9a8a&quot;, &quot;fillColor&quot;: &quot;#1f9a8a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#3e4c8a&quot;, &quot;fillColor&quot;: &quot;#3e4c8a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_f4f432e340e6337c45e24db4bcfd3a9c_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f4f432e340e6337c45e24db4bcfd3a9c_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_f4f432e340e6337c45e24db4bcfd3a9c_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f4f432e340e6337c45e24db4bcfd3a9c_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_f4f432e340e6337c45e24db4bcfd3a9c.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f4f432e340e6337c45e24db4bcfd3a9c_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f4f432e340e6337c45e24db4bcfd3a9c = L.geoJson(null, {
#                 onEachFeature: geo_json_f4f432e340e6337c45e24db4bcfd3a9c_onEachFeature,
#
#                 style: geo_json_f4f432e340e6337c45e24db4bcfd3a9c_styler,
#                 pointToLayer: geo_json_f4f432

# %% [markdown]
# ## Geometry Manipulations
#
# GeoPandas provides several methods for manipulating geometries, we will just explore buffering.
#
# ### Buffering Geometries
#
# We can create a buffer zone around each borough:

# %%
# Buffer the boroughs by 10000 feet
gdf["buffered"] = gdf.buffer(10000)

# Plot the buffered geometries
gdf["buffered"].plot(alpha=0.3, edgecolor="yellow")
plt.title("Buffered NYC Boroughs (10,000 feet)")
plt.show()

# %% [markdown]
# ## Spatial Queries and Relations
#
# We can also perform spatial queries to examine relationships between geometries. For instance, we can check which boroughs are within a certain distance of Manhattan.
#
# ### Checking for Intersections
#
# We can find which boroughs' buffered areas intersect with the original geometry of Manhattan:

# %%
# Get the geometry of Manhattan
manhattan_geom = gdf.loc["Manhattan", "geometry"]

# Check which buffered boroughs intersect with Manhattan's geometry
gdf["intersects_manhattan"] = gdf["buffered"].intersects(manhattan_geom)
gdf[["intersects_manhattan"]]
# Out:
#                intersects_manhattan
# BoroName
# Staten Island                 False
# Queens                         True
# Brooklyn                       True
# Manhattan                      True
# Bronx                          True

# %% [markdown]
# ### Checking for Containment
#
# Similarly, we can check if the centroids are contained within the borough boundaries:

# %%
# Check if centroids are within the original borough geometries
gdf["centroid_within_borough"] = gdf["centroid"].within(gdf["geometry"])
gdf[["centroid_within_borough"]]
# Out:
#                centroid_within_borough
# BoroName
# Staten Island                     True
# Queens                            True
# Brooklyn                          True
# Manhattan                         True
# Bronx                             True

# %% [markdown]
# ## Projections and Coordinate Reference Systems (CRS)
#
# GeoPandas makes it easy to manage projections. Each GeoSeries and GeoDataFrame has a crs attribute that defines its CRS.
#
# ### Checking the CRS
#
# Let's check the CRS of the boroughs dataset:

# %%
print(gdf.crs)
# Out:
# EPSG:2263

# %% [markdown]
# The CRS for this dataset is [`EPSG:2263`](https://epsg.io/2263) (NAD83 / New York State Plane). We can reproject the geometries to WGS84 ([`EPSG:4326`](https://epsg.io/4326)), which uses latitude and longitude coordinates.
#
# [EPSG](https://epsg.io) stands for European Petroleum Survey Group, which was a scientific organization that standardized geodetic and coordinate reference systems. EPSG codes are unique identifiers that represent coordinate systems and other geodetic properties.
#
# ### Reprojecting to WGS84

# %%
# Reproject the GeoDataFrame to WGS84 (EPSG:4326)
gdf_4326 = gdf.to_crs(epsg=4326)

# Plot the reprojected geometries
gdf_4326.plot(figsize=(10, 6), edgecolor="black")
plt.title("NYC Boroughs in WGS84 (EPSG:4326)")
plt.show()

# %% [markdown]
# Notice how the coordinates have changed from feet to degrees.

# %% [markdown]
# ## Exercises
#
# 1. Download the dataset (two shapefiles) from [this website](https://www.naturalearthdata.com/downloads/110m-cultural-vectors/): Admin 0 – Countries and Populated Places to your workspace folder, unzip them.
# 2. Load the shapefiles to two different GeoDataFrames.
# 3. Perform a spatial join between two GeoDataFrames: one containing polygons (e.g., country borders) and one containing points (e.g., cities). Find out which points fall within which polygons.

# %%
url1 = "/Users/xiaozhongsun/Desktop/geog346_s25/data/ne_110m_populated_places/ne_110m_populated_places.shp"
gdf_city = gpd.read_file(url1)
gdf_city.head()
# Out:
#    SCALERANK  NATSCALE  LABELRANK           FEATURECLA          NAME NAMEPAR  \
# 0          8        10          3      Admin-0 capital  Vatican City    None
# 1          7        20          0      Admin-0 capital    San Marino    None
# 2          7        20          0      Admin-0 capital         Vaduz    None
# 3          6        30          8  Admin-0 capital alt       Lobamba    None
# 4          6        30          8      Admin-0 capital    Luxembourg    None
#
#   NAMEALT     NAMEASCII  ADM0CAP            CAPIN  ...  FCLASS_ID  FCLASS_PL  \
# 0    None  Vatican City        1             None  ...       None       None
# 1    None    San Marino        1             None  ...       None       None
# 2    None         Vaduz        1             None  ...       None       None
# 3    None       Lobamba        0  Legislative and  ...       None       None
# 4    None    Luxembourg        1             None  ...       None       None
#
#   FCLASS_GR FCLASS_IT FCLASS_NL FCLASS_SE FCLASS_BD FCLASS_UA FCLASS_TLC  \
# 0      None      None      None      None      None      None       None
# 1      None      None      None      None      None      None       None
# 2      None      None      None      None      None      None       None
# 3      None      None      None      None      None      None       None
# 4      None      None      None      None      None      None       None
#
#                     geometry
# 0  POINT (12.45339 41.90328)
# 1   POINT (12.44177 43.9361)
# 2   POINT (9.51667 47.13372)
# 3     POINT (31.2 -26.46667)
# 4      POINT (6.13 49.61166)
#
# [5 rows x 138 columns]

# %%
url2 = "/Users/xiaozhongsun/Desktop/geog346_s25/data/ne_110m_admin_0_countries/ne_110m_admin_0_countries.shp"
gdf_country = gpd.read_file(url2)
gdf_country.head()
# Out:
#         featurecla  scalerank  LABELRANK                   SOVEREIGNT SOV_A3  \
# 0  Admin-0 country          1          6                         Fiji    FJI
# 1  Admin-0 country          1          3  United Republic of Tanzania    TZA
# 2  Admin-0 country          1          7               Western Sahara    SAH
# 3  Admin-0 country          1          2                       Canada    CAN
# 4  Admin-0 country          1          2     United States of America    US1
#
#    ADM0_DIF  LEVEL               TYPE TLC                        ADMIN  ...  \
# 0         0      2  Sovereign country   1                         Fiji  ...
# 1         0      2  Sovereign country   1  United Republic of Tanzania  ...
# 2         0      2      Indeterminate   1               Western Sahara  ...
# 3         0      2  Sovereign country   1                       Canada  ...
# 4         1      2            Country   1     United States of America  ...
#
#       FCLASS_TR     FCLASS_ID     FCLASS_PL FCLASS_GR  FCLASS_IT  \
# 0          None          None          None      None       None
# 1          None          None          None      None       None
# 2  Unrecognized  Unrecognized  Unrecognized      None       None
# 3          None          None          None      None       None
# 4          None          None          None      None       None
#
#       FCLASS_NL FCLASS_SE  FCLASS_BD FCLASS_UA  \
# 0          None      None       None      None
# 1          None      None       None      None
# 2  Unrecognized      None       None      None
# 3          None      None       None      None
# 4          None      None       None      None
#
#                                             geometry
# 0  MULTIPOLYGON (((180 -16.06713, 180 -16.55522, ...
# 1  POLYGON ((33.90371 -0.95, 34.07262 -1.05982, 3...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84 49, -122.97421 49.0025...
# 4  MULTIPOLYGON (((-122.84 49, -120 49, -117.0312...
#
# [5 rows x 169 columns]

# %%
# Create a base map from the country boundaries.
# Here we set fillOpacity to 0 so that only the boundaries are shown.
m = gdf_city.explore(
    marker_kwds=dict(color="darkblue", radius=5),
    tooltip=["NAME"],  # shows country names when you hover
    name="Capital"
)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c52346aeaf25ff840827e0f1b67b595 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c52346aeaf25ff840827e0f1b67b595&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c52346aeaf25ff840827e0f1b67b595 = L.map(
#                 &quot;map_6c52346aeaf25ff840827e0f1b67b595&quot;,
#                 {
#                     center: [11.425695735427617, 1.998041299999997],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_6c52346aeaf25ff840827e0f1b67b595);
#
#
#
#
#
#             var tile_layer_0732866f6513577d26bed44ae380b163 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0732866f6513577d26bed44ae380b163.addTo(map_6c52346aeaf25ff840827e0f1b67b595);
#
#
#             map_6c52346aeaf25ff840827e0f1b67b595.fitBounds(
#                 [[-41.2920679923151, -175.2205645], [64.14345946317033, 179.2166471]],
#                 {}
#             );
#
#
#         function geo_json_322d26c2d9d2e86846723241489e9ed3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_322d26c2d9d2e86846723241489e9ed3_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_322d26c2d9d2e86846723241489e9ed3_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_322d26c2d9d2e86846723241489e9ed3_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_322d26c2d9d2e86846723241489e9ed3_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_322d26c2d9d2e86846723241489e9ed3.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_322d26c2d9d2e86846723241489e9ed3_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_322d26c2d9d2e86846723241489e9ed3 = L.geoJson(null, {
#                 onEachFeature: geo_json_322d26c2d9d2e86846723241489e9ed3_onEachFeature,
#
#                 style: geo_json_322d26c2d9d2e86846723241489e9ed3_styler,
#                 pointToLayer: geo_json_322d26c2d9d2e86846723241489e9ed3_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_322d26c2d9d2e86846723241489e9ed3_add (data) {
#             geo_json_322d26c2d9d2e86846723241489e9ed3
#                 .addData(data);
#         }
#             geo_json_322d26c2d9d2e86846723241489e9ed3_add({&quot;bbox&quot;: [-175.2205645, -41.2920679923151, 179.2166471, 64.14345946317033], &quot;features&quot;: [{&quot;bbox&quot;: [12.4533865, 41.9032822, 12.4533865, 41.9032822], &quot;geometry&quot;: {&quot;coordinates&quot;: [12.4533865, 41.9032822], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;ADM0CAP&quot;: 1, &quot;ADM0NAME&quot;: &quot;Vatican&quot;, &quot;ADM0_A3&quot;: &quot;VAT&quot;, &quot;ADM1NAME&quot;: &quot;Lazio&quot;, &quot;CAPALT&quot;: 0, &quot;CAPIN&quot;: null, &quot;FCLASS_AR&quot;: null, &quot;FCLASS_BD&quot;: null, &quot;FCLASS_BR&quot;: null, &quot;FCLASS_CN&quot;: null, &quot;FCLASS_DE&quot;: null, &quot;FCLASS_EG&quot;: null, &qu

# %%
# Ensure both GeoDataFrames are in the same CRS (typically EPSG:4326 for Natural Earth data)
gdf_country = gdf_country.to_crs("EPSG:4326")
gdf_city = gdf_city.to_crs("EPSG:4326")

# Step 3: Perform a spatial join to join cities (points) with country polygons.
# This operation finds the country polygon that each city falls within.
joined_gdf = gpd.sjoin(gdf_city, gdf_country, how="left", predicate="within")

# %%
joined_gdf.head()
# Out:
#    SCALERANK  NATSCALE  LABELRANK_left           FEATURECLA     NAME_left  \
# 0          8        10               3      Admin-0 capital  Vatican City
# 1          7        20               0      Admin-0 capital    San Marino
# 2          7        20               0      Admin-0 capital         Vaduz
# 3          6        30               8  Admin-0 capital alt       Lobamba
# 4          6        30               8      Admin-0 capital    Luxembourg
#
#   NAMEPAR NAMEALT     NAMEASCII  ADM0CAP            CAPIN  ...  \
# 0    None    None  Vatican City        1             None  ...
# 1    None    None    San Marino        1             None  ...
# 2    None    None         Vaduz        1             None  ...
# 3    None    None       Lobamba        0  Legislative and  ...
# 4    None    None    Luxembourg        1             None  ...
#
#    FCLASS_VN_right  FCLASS_TR_right FCLASS_ID_right FCLASS_PL_right  \
# 0             None             None            None            None
# 1             None             None            None            None
# 2             None             None            None            None
# 3             None             None            None            None
# 4             None             None            None            None
#
#   FCLASS_GR_right FCLASS_IT_right FCLASS_NL_right FCLASS_SE_right  \
# 0            None            None            None            None
# 1            None            None            None            None
# 2            None            None            None            None
# 3            None            None            None            None
# 4            None            None            None            None
#
#   FCLASS_BD_right  FCLASS_UA_right
# 0            None             None
# 1            None             None
# 2            None             None
# 3            None             None
# 4            None             None
#
# [5 rows x 307 columns]

# %%
# Create a base map from the country boundaries.
# Here we set fillOpacity to 0 so that only the boundaries are shown.
m = gdf_country.explore(
    style_kwds={'fillOpacity': 0, 'color': 'black'},
    tooltip=["SOVEREIGNT"],  # shows country names when you hover
    name="Countries"
)

# Add the capital points from the joined GeoDataFrame to the same map.
# Adjust the marker_kwds as needed (color, size, etc.)
joined_gdf.explore(
    m=m,
    marker_kwds=dict(color="darkblue", radius=5),
    tooltip=["NAME_left", "SOVEREIGNT"],  # typically the capital name (adjust the field if necessary)
    name="Capitals"
)

# Display the interactive map with both layers.
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cab900597d5e416fe4f6939b94c7664d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cab900597d5e416fe4f6939b94c7664d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cab900597d5e416fe4f6939b94c7664d = L.map(
#                 &quot;map_cab900597d5e416fe4f6939b94c7664d&quot;,
#                 {
#                     center: [-3.1774349999999956, 2.842170943040401e-14],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_cab900597d5e416fe4f6939b94c7664d);
#
#
#
#
#
#             var tile_layer_c71cf178d733db0d0c1142f7ef130b92 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c71cf178d733db0d0c1142f7ef130b92.addTo(map_cab900597d5e416fe4f6939b94c7664d);
#
#
#             map_cab900597d5e416fe4f6939b94c7664d.fitBounds(
#                 [[-90.0, -180.0], [83.64513000000001, 180.00000000000006]],
#                 {}
#             );
#
#
#         function geo_json_f587a942697bc913a823239feef83d83_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_f587a942697bc913a823239feef83d83_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f587a942697bc913a823239feef83d83_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_f587a942697bc913a823239feef83d83_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f587a942697bc913a823239feef83d83_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_f587a942697bc913a823239feef83d83.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f587a942697bc913a823239feef83d83_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f587a942697bc913a823239feef83d83 = L.geoJson(null, {
#                 onEachFeature: geo_json_f587a942697bc913a823239feef83d83_onEachFeature,
#
#                 style: geo_json_f587a942697bc913a823239feef83d83_styler,
#                 pointToLayer: geo_json_f587a942697bc913a823239feef83d83_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_f587a942697bc913a823239feef83d83_add (data) {
#             geo_json_f587a942697bc913a823239feef83d83
#                 .addData(data);
#         }
#             geo_json_f587a942697bc913a823239feef83d83_add({&quot;bbox&quot;: [-180.0, -90.0, 180.00000000000006, 83.64513000000001], &quot;features&quot;: [{&quot;bbox&quot;: [-180.0, -18.28799, 180.0, -16

# %% [markdown]
# ## Summary
#
# This lecture provided an introduction to working with geospatial data using GeoPandas. We covered basic concepts such as reading/writing geospatial data, performing spatial operations (e.g., buffering, intersections), and visualizing geospatial data using maps. GeoPandas, built on Pandas and Shapely, enables efficient and intuitive geospatial analysis in Python.
